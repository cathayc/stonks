# %%
from main import Stock
import article_search

# %%
apple =  Stock("SEDG")

# %%
apple.plot_min_max()
# Out:
# Plotting close values

# %%
gaussian_values = apple.get_gaussian_values(3)

# %%
apple.plot_min_max(gaussian_values)

# %%
my_min, my_max = apple.get_min_max(gaussian_values)
x = apple.df.index
print(x[my_max])
print(x[my_min])
# Out:
# DatetimeIndex(['2019-12-26', '2020-01-13', '2020-01-22', '2020-02-05',
#                '2020-02-21', '2020-03-04', '2020-03-26', '2020-04-14',
#                '2020-04-29', '2020-05-12', '2020-05-21', '2020-06-02',
#                '2020-06-08', '2020-06-19', '2020-07-27', '2020-08-14',
#                '2020-08-31', '2020-09-15', '2020-10-16', '2020-11-09',
#                '2020-11-27', '2020-12-23', '2021-01-08', '2021-01-22',
#                '2021-02-16', '2021-02-26', '2021-03-12', '2021-03-22',
#                '2021-04-01', '2021-04-13', '2021-04-27', '2021-05-27',
#                '2021-06-29', '2021-07-22', '2021-08-09', '2021-08-31',
#                '2021-09-16', '2021-09-23', '2021-10-19', '2021-11-01',
#                '2021-11-15', '2021-12-08', '2021-12-23'],
#               dtype='datetime64[ns]', name='Date', freq=None)
# DatetimeIndex(['2019-12-27', '2020-01-14', '2020-01-31', '2020-02-07',
#                '2020-02-28', '2020-03-20', '2020-04-02', '2020-04-21',
#                '2020-05-04', '2020-05-13', '2020-05-22', '2020-06-04',
#                '2020-06-11', '2020-06-26', '2020-07-28', '2020-08-25',
#                '2020-09-10', '2020-09-21', '2020-11-04', '2020-11-13',
#                '2020-12-03', '2020-12-29', '2021-01-19', '2021-01-28',
#                '2021-02-25', '2021-03-05', '2021-03-19', '2021-03-26',
#                '2021-04-09', '2021-04-19', '2021-05-12', '2021-06-08',
#                '2021-07-16', '2021-07-26', '2021-08-18', '2021-09-10',
#                '2021-09-20', '2021-10-05', '2021-10-21', '2021-11-05',
#                '2021-12-03', '2021-12-20', '2021-12-29'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
response = article_search.search_tickerTick("SEDG", x[my_max][4])
print(x[my_max][4])
# Out:
# 2020-04-15 00:00:00

# %%
article_search.extract_searchTick_response(response)
# Out:
# [{'title': 'SOLAREDGE TECHNOLOGIES, INC.: Form DEFA14A - 2020-04-07',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1419612/0001178913-20-001056-index.html',
#   'site': 'sec.gov',
#   'time': datetime.datetime(2020, 4, 7, 0, 0)},
#  {'title': 'SOLAREDGE TECHNOLOGIES, INC.: Form 4 - 2020-04-07',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1419612/0001178913-20-001064-index.html',
#   'site': 'sec.gov',
#   'time': datetime.datetime(2020, 4, 7, 0, 0)},
#  {'title': 'SOLAREDGE TECHNOLOGIES, INC.: Form DEF 14A - 2020-04-07',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1419612/0001178913-20-001054-index.html',
#   'site': 'sec.gov',
#   'time': datetime.datetime(2020, 4, 7, 0, 0)},
#  {'title': 'SOLAREDGE TECHNOLOGIES, INC.: Form 4 - 2020-04-03',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1419612/0001178913-20-001017-index.html',
#   'site': 'sec.gov',
#   'time': datetime.datetime(2020, 4, 3, 0, 0)},
#  {'title': 'SolarEdge Stock Jumps Despite Lukewarm Initiation',
#   'url': 'https://www.fool.com/investing/2020/03/25/solaredge-stock-jumps-despite-lukewarm-initiation.aspx?source=iedfolrf0000001',
#   'site': 'fool.com',
#   'time': datetime.datetime(2020, 3, 25, 19, 36, 57)}]
