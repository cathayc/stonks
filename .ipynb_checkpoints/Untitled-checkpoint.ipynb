# %%
from main import Stock
import article_search

# %%
apple =  Stock("SEDG")

# %%
apple.plot_min_max()
# Out:
# Plotting close values

# %%
gaussian_values = apple.get_gaussian_values(5)

# %%
apple.plot_min_max(gaussian_values)

# %%
my_min, my_max = apple.get_min_max(gaussian_values)
x = apple.df.index
print(x[my_max])
print(x[my_min])
# Out:
# DatetimeIndex(['2020-01-22', '2020-02-24', '2020-03-03', '2020-03-26',
#                '2020-04-15', '2020-06-05', '2020-06-19', '2020-08-17',
#                '2020-08-28', '2020-09-15', '2020-10-15', '2020-11-10',
#                '2020-11-30', '2020-12-23', '2021-01-08', '2021-01-21',
#                '2021-02-12', '2021-03-15', '2021-03-31', '2021-04-27',
#                '2021-05-26', '2021-06-30', '2021-08-09', '2021-08-31',
#                '2021-09-23', '2021-11-02', '2021-11-16', '2021-12-27'],
#               dtype='datetime64[ns]', name='Date', freq=None)
# DatetimeIndex(['2020-01-30', '2020-02-28', '2020-03-20', '2020-04-01',
#                '2020-04-17', '2020-06-11', '2020-06-29', '2020-08-25',
#                '2020-09-10', '2020-09-21', '2020-11-06', '2020-11-12',
#                '2020-12-03', '2020-12-29', '2021-01-20', '2021-01-28',
#                '2021-03-05', '2021-03-26', '2021-04-19', '2021-05-12',
#                '2021-06-08', '2021-07-16', '2021-08-19', '2021-09-13',
#                '2021-10-05', '2021-11-08', '2021-12-21'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
response = article_search.search_tickerTick("SEDG", x[my_max][2])
# Out:
# b'{\n  "stories": [\n    {\n      "id": "8498878165206105179",\n      "title": "SOLAREDGE TECHNOLOGIES, INC.: Form 10-K - 2020-02-27",\n      "url": "https://www.sec.gov/Archives/edgar/data/1419612/0001178913-20-000672-index.html",\n      "site": "sec.gov",\n      "time": 1582790400000,\n      "favicon_url": "https://static.tickertick.com/website_icons/sec.gov.ico",\n      "tags": [\n        "sedg"\n      ]\n    },\n    {\n      "id": "-4699661398760421977",\n      "title": "SolarEdge Technologies, Tilly\'s, Darling Ingredients, Lamb Weston and Hain Celestial highlighted as Zacks Bull and Bear of the Day",\n      "url": "https://finance.yahoo.com/news/solaredge-technologies-tillys-darling-ingredients-131901630.html?.tsrc=rss",\n      "site": "yahoo.com",\n      "time": 1582751941000,\n      "favicon_url": "https://static.tickertick.com/website_icons/yahoo.com.ico",\n      "tags": [\n        "sedg"\n      ]\n    },\n    {\n      "id": "7586787312879249614",\n      "title": "Solar Stocks Extend February Rally; This Leader In Buy Range Ahead Of Earnings",\n      "url": "http://feedproxy.google.com/~r/ibdindustrythemesRSS/~3/PCeV3lPP4U4/",\n      "site": "google.com",\n      "time": 1582320921000,\n      "favicon_url": "https://static.tickertick.com/website_icons/google.com.ico",\n      "tags": [\n        "sedg"\n      ],\n      "description": "Solar stocks accelerated to the top of the market in February. Enphase and SolarEdge scored big gains in the past week. Sunrun reports on Thursday. The post Solar Stocks Extend February Rally; This Leader In Buy Range Ahead Of Earnings appeared first on Investor\'s Business Daily ."\n    },\n    {\n      "id": "-5681903257430276552",\n      "title": "SolarEdge Technologies stock price target cut to $337 from $386 at J.P. Morgan",\n      "url": "http://feeds.marketwatch.com/~r/marketwatch/realtimeheadlines/~3/mKKTEmMEimA/quotes.asp",\n      "site": "marketwatch.com",\n      "time": 1582205985000,\n      "favicon_url": "https://static.tickertick.com/website_icons/marketwatch.com.ico",\n      "tags": [\n        "sedg"\n      ]\n    },\n    {\n      "id": "-2650647222225250673",\n      "title": "SOLAREDGE TECHNOLOGIES, INC.: Form 4 - 2020-02-20",\n      "url": "https://www.sec.gov/Archives/edgar/data/1419612/0001178913-20-000618-index.html",\n      "site": "sec.gov",\n      "time": 1582185600000,\n      "favicon_url": "https://static.tickertick.com/website_icons/sec.gov.ico",\n      "tags": [\n        "sedg"\n      ]\n    }\n  ],\n  "last_id": "-2650647222225250673"\n}'
