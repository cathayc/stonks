# %%
from main import Stock
import article_search

# %%
apple =  Stock("AAPL")
# Out:
# [*********************100%***********************]  1 of 1 completed
# <bound method NDFrame.head of                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  133.520004  133.610001  126.760002  129.410004  127.679985
# 2021-01-05  128.889999  131.740005  128.429993  131.009995  129.258606
# 2021-01-06  127.720001  131.050003  126.379997  126.599998  124.907570
# 2021-01-07  128.360001  131.630005  127.860001  130.919998  129.169800
# 2021-01-08  132.429993  132.630005  130.229996  132.050003  130.284698
# ...                ...         ...         ...         ...         ...
# 2021-12-27  177.089996  180.419998  177.070007  180.330002  179.016129
# 2021-12-28  180.160004  181.330002  178.529999  179.289993  177.983673
# 2021-12-29  179.330002  180.630005  178.139999  179.380005  178.073044
# 2021-12-30  179.470001  180.570007  178.089996  178.199997  176.901642
# 2021-12-31  178.089996  179.229996  177.259995  177.570007  176.276230
#
# ...

# %%
apple.plot_min_max()
# Out:
# Plotting close values

# %%
gaussian_values = apple.get_gaussian_values(3)

# %%
apple.plot_min_max(gaussian_values)

# %%
my_min, my_max = apple.get_min_max(gaussian_values)
x = apple.df.index
print(x[my_max])
print(x[my_min])
# Out:
# DatetimeIndex(['2021-01-08', '2021-01-26', '2021-02-05', '2021-03-01',
#                '2021-03-16', '2021-03-22', '2021-04-16', '2021-04-26',
#                '2021-05-17', '2021-05-25', '2021-07-14', '2021-07-23',
#                '2021-08-04', '2021-08-16', '2021-08-24', '2021-09-07',
#                '2021-09-23', '2021-10-08', '2021-10-21', '2021-10-28',
#                '2021-11-04', '2021-11-23', '2021-12-10', '2021-12-28'],
#               dtype='datetime64[ns]', name='Date', freq=None)
# DatetimeIndex(['2021-01-05', '2021-01-15', '2021-02-01', '2021-02-25',
#                '2021-03-08', '2021-03-19', '2021-03-25', '2021-04-21',
#                '2021-05-12', '2021-05-18', '2021-06-02', '2021-07-19',
#                '2021-07-29', '2021-08-09', '2021-08-19', '2021-08-25',
#                '2021-09-21', '2021-10-04', '2021-10-12', '2021-10-22',
#                '2021-11-01', '2021-11-11', '2021-11-26', '2021-12-20'],
# ...

# %%
import numpy as np
i = 0
diff_arr = []
while (i < min([len(x[my_max]), len(x[my_min])])):
    diff_arr.append((x[my_max][i]-x[my_min][i]).days)
    print(x[my_max][i]-x[my_min][i])
    i+=1
    
print(np.mean(diff_arr))
# Out:
# 3 days 00:00:00
# 11 days 00:00:00
# 4 days 00:00:00
# 4 days 00:00:00
# 8 days 00:00:00
# 3 days 00:00:00
# 22 days 00:00:00
# 5 days 00:00:00
# 5 days 00:00:00
# 7 days 00:00:00
# 42 days 00:00:00
# 4 days 00:00:00
# 6 days 00:00:00
# 7 days 00:00:00
# 5 days 00:00:00
# 13 days 00:00:00
# 2 days 00:00:00
# 4 days 00:00:00
# 9 days 00:00:00
# 6 days 00:00:00
# 3 days 00:00:00
# 12 days 00:00:00
# 14 days 00:00:00
# 8 days 00:00:00
# 8.625

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
plt.plot(diff_arr, '-ok', color='black');
# Out:
# /var/folders/vx/sg272dzd4j18b1yt72sw_ml40000gn/T/ipykernel_15338/3172203788.py:4: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(diff_arr, '-ok', color='black');

# %%
response = article_search.search_tickerTick("SEDG", x[my_max][5])
print(x[my_max][5])
# Out:
# 2021-03-22 00:00:00

# %%
stories = article_search.extract_searchTick_response(response)

# %%
#article_search.open_pages(stories)

# %%
articles = article_search.search_nyt("Apple", x[my_max][5], x[my_max][5])
articles
# Out:
# [{'abstract': 'Yes, tech companies are hiring. Here’s why they want you to notice.',
#   'web_url': 'https://www.nytimes.com/2021/03/23/technology/big-tech-jobs-politics.html',
#   'snippet': 'Yes, tech companies are hiring. Here’s why they want you to notice.',
#   'lead_paragraph': 'This article is part of the On Tech newsletter. You can sign up here to receive it weekdays.',
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2021/03/23/business/23OnTech-jobs/23OnTech-jobs-articleLarge.gif',
#     'height': 400,
#     'width': 600,
#     'legacy': {'xlarge': 'images/2021/03/23/business/23OnTech-jobs/23OnTech-jobs-articleLarge.gif',
#      'xlargewidth': 600,
#      'xlargeheight': 400},
#     'subType': 'xlarge',
#     'crop_name': 'articleLarge'},
#    {'rank': 0,
#     'subtype': 'popup',
#     'caption': None,
#     'credit': None,
# ...

# %%
article_search.open_pages(articles, url='web_url')
